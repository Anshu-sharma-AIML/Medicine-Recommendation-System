# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay
import joblib

# %%
# Load datasets
medicine_df = pd.read_csv("medicine_dataset.csv")
symptom_df = pd.read_csv("symptom_dataset.csv")

# Merge on Indication
merged_df = pd.merge(symptom_df, medicine_df, on="Indication", how="inner")

# Save final merged dataset
merged_df.to_csv("merged_symptom_medicine_dataset.csv", index=False)

# Download final file
files.download("merged_symptom_medicine_dataset.csv")

print("merged_symptom_medicine_dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[13], line 6
#       3 symptom_df = pd.read_csv("symptom_dataset.csv")
#       5 # Merge on Indication
# ----> 6 merged_df = pd.merge(symptom_df, medicine_df, on="Indication", how="inner")
#       8 # Save final merged dataset
#       9 merged_df.to_csv("merged_symptom_medicine_dataset.csv", index=False)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\reshape\merge.py:162, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     131 @Substitution("\nleft : DataFrame or named Series")
#     132 @Appender(_merge_doc, indents=0)
#     133 def merge(
#    (...)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
#     148     op = _MergeOperation(
# ...

# %%
# vals = dataset.values.flatten()
dataset

# %%
dataset.shape

# %%
len(dataset['prognosis'].unique())

# %%
print(dataset.columns)
